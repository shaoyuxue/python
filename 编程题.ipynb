# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel(r'C:\Users\shaoyumei\Desktop\产品成本还原（面试）.xlsx')
df
# Out:
#    订单号  订单行号 产品编码   规格型号 基本单位 产品批号 成本项目名称       本期成本   数量            金额
# 0   D1     1   A1  0.2ml    件   Z1    NaN  49.214000    5    246.070000
# 1   D1     1   A1  0.2ml    件   Z1   直接材料  39.097202    5    195.486009
# 2   D1     1   A1  0.2ml    件   Z1   间接材料   1.495123    5      7.475615
# 3   D1     1   A1  0.2ml    件   Z1   间接材料        NaN    5           NaN
# 4   D1     1   A1  0.2ml    件   Z1   直接人工   3.203641    5     16.018206
# 5   D1     1   A1  0.2ml    件   Z1   折旧费用   0.222439    5      1.112193
# 6   D1     1   A1  0.2ml    件   Z1   辅助费用   4.940668    5     24.703338
# 7   D1     1   A1  0.2ml    件   Z1   其他费用   0.230243    5      1.151215
# 8   D2     1   A1  0.2ml    件   Z2    NaN  49.205000    2     98.410000
# 9   D2     1   A1  0.2ml    件   Z2   直接材料  39.104366    2     78.208731
# 10  D2     1   A1  0.2ml    件   Z2   间接材料   1.484076    2      2.968152
# 11  D2     1   A1  0.2ml    件   Z2   间接材料        NaN    2           NaN
# 12  D2     1   A1  0.2ml    件   Z2   直接人工   3.203588    2      6.407175
# 13  D2     1   A1  0.2ml    件   Z2   折旧费用   0.221435    2      0.442870
# 14  D2     1   A1  0.2ml    件   Z2   辅助费用   4.941590    2      9.883180
# 15  D2     1   A1  0.2ml    件   Z2   其他费用   0.225240    2      0.450479
# 16  D3     1   A2  0.5ml    件   A3    NaN  62.285333   15    934.280000
# 17  D3     1   A2  0.5ml    件   A3   直接材料  53.254482   15    798.817235
# 18  D3     1   A2  0.5ml    件   A3   间接材料   1.558012   15     23.370173
# 19  D3     1   A2  0.5ml    件   A3   间接材料        NaN   15           NaN
# 20  D3     1   A2  0.5ml    件   A3   直接人工   3.093946   15     46.409191
# 21  D3     1   A2  0.5ml    件   A3   折旧费用   0.185178   15      2.777667
# 22  D3     1   A2  0.5ml    件   A3   辅助费用   3.954047   15     59.310703
# 23  D3     1   A2  0.5ml    件   A3   其他费用   0.239049   15      3.585728
# 24  D4     1   A2  0.5ml    件   Z4    NaN  62.270000    4    249.080000
# 25  D4     1   A2  0.5ml    件   Z4   直接材料  53.260687    4    213.042746
# 26  D4     1   A2  0.5ml    件   Z4   间接材料   1.536531    4      6.146123
# 27  D4     1   A2  0.5ml    件   Z4   间接材料        NaN    4           NaN
# 28  D4     1   A2  0.5ml    件   Z4   直接人工   3.092826    4     12.371303
# 29  D4     1   A2  0.5ml    件   Z4   折旧费用   0.186014    4      0.744054
# 30  D4     1   A2  0.5ml    件   Z4   辅助费用   3.951098    4     15.804393
# 31  D4     1   A2  0.5ml    件   Z4   其他费用   0.242219    4      0.968875
# 32  D5     1   A3    1ml    件   Z5    NaN  83.689000   10    836.890000
# 33  D5     1   A3    1ml    件   Z5   直接材料  72.517826   10    725.178264
# 34  D5     1   A3    1ml    件   Z5   间接材料   1.536353   10     15.363534
# 35  D5     1   A3    1ml    件   Z5   直接人工   3.718527   10     37.185271
# 36  D5     1   A3    1ml    件   Z5   折旧费用   0.257915   10      2.579150
# 37  D5     1   A3    1ml    件   Z5   辅助费用   5.257218   10     52.572184
# 38  D5     1   A3    1ml    件   Z5   其他费用   0.400647   10      4.006468
# 39  D6     4   A4    1ml    件   Z6    NaN  81.409000   20   1628.180000
# 40  D6     4   A4    1ml    件   Z6   直接材料  72.237387   20   1444.747745
# 41  D6     4   A4    1ml    件   Z6   间接材料   0.834262   20     16.685239
# 42  D6     4   A4    1ml    件   Z6   直接人工   3.133952   20     62.679037
# 43  D6     4   A4    1ml    件   Z6   折旧费用   0.208799   20      4.175974
# 44  D6     4   A4    1ml    件   Z6   辅助费用   4.406426   20     88.128516
# 45  D6     4   A4    1ml    件   Z6   其他费用   0.587332   20     11.746646
# 46  D7     1   A4    1ml    件   Z6    NaN  81.408200  150  12211.230000
# 47  D7     1   A4    1ml    件   Z6   间接材料   0.840164  150    126.024664
# 48  D7     1   A4    1ml    件   Z6   直接人工   3.134021  150    470.103098
# 49  D7     1   A4    1ml    件   Z6   折旧费用   0.208866  150     31.329826
# 50  D7     1   A4    1ml    件   Z6   辅助费用   4.408629  150    661.294280
# 51  D7     1   A4    1ml    件   Z6   其他费用   0.587766  150     88.164912

# %%
df_zc=df.query('成本项目名称=="直接材料"')
df_zc
# Out:
#    订单号  订单行号 产品编码   规格型号 基本单位 产品批号 成本项目名称       本期成本  数量           金额
# 1   D1     1   A1  0.2ml    件   Z1   直接材料  39.097202   5   195.486009
# 9   D2     1   A1  0.2ml    件   Z2   直接材料  39.104366   2    78.208731
# 17  D3     1   A2  0.5ml    件   A3   直接材料  53.254482  15   798.817235
# 25  D4     1   A2  0.5ml    件   Z4   直接材料  53.260687   4   213.042746
# 33  D5     1   A3    1ml    件   Z5   直接材料  72.517826  10   725.178264
# 40  D6     4   A4    1ml    件   Z6   直接材料  72.237387  20  1444.747745

# %%
s1=df_zc.groupby('产品编码')['金额'].sum()
df1=pd.DataFrame({"直接材料合计":s1})
df1
# Out:
#            直接材料合计
# 产品编码
# A1     273.694740
# A2    1011.859981
# A3     725.178264
# A4    1444.747745

# %%
s2=df_zc.groupby('产品编码')['本期成本'].mean()
df2=pd.DataFrame({"直接材料平均单价":s2})
df2
# Out:
#        直接材料平均单价
# 产品编码
# A1    39.100784
# A2    53.257585
# A3    72.517826
# A4    72.237387

# %%
df_jc=df.query('成本项目名称=="间接材料"')
df_jc
# Out:
#    订单号  订单行号 产品编码   规格型号 基本单位 产品批号 成本项目名称      本期成本   数量          金额
# 2   D1     1   A1  0.2ml    件   Z1   间接材料  1.495123    5    7.475615
# 3   D1     1   A1  0.2ml    件   Z1   间接材料       NaN    5         NaN
# 10  D2     1   A1  0.2ml    件   Z2   间接材料  1.484076    2    2.968152
# 11  D2     1   A1  0.2ml    件   Z2   间接材料       NaN    2         NaN
# 18  D3     1   A2  0.5ml    件   A3   间接材料  1.558012   15   23.370173
# 19  D3     1   A2  0.5ml    件   A3   间接材料       NaN   15         NaN
# 26  D4     1   A2  0.5ml    件   Z4   间接材料  1.536531    4    6.146123
# 27  D4     1   A2  0.5ml    件   Z4   间接材料       NaN    4         NaN
# 34  D5     1   A3    1ml    件   Z5   间接材料  1.536353   10   15.363534
# 41  D6     4   A4    1ml    件   Z6   间接材料  0.834262   20   16.685239
# 47  D7     1   A4    1ml    件   Z6   间接材料  0.840164  150  126.024664

# %%
df_jc_1=df_jc.dropna()
df_jc_1
# Out:
#    订单号  订单行号 产品编码   规格型号 基本单位 产品批号 成本项目名称      本期成本   数量          金额
# 2   D1     1   A1  0.2ml    件   Z1   间接材料  1.495123    5    7.475615
# 10  D2     1   A1  0.2ml    件   Z2   间接材料  1.484076    2    2.968152
# 18  D3     1   A2  0.5ml    件   A3   间接材料  1.558012   15   23.370173
# 26  D4     1   A2  0.5ml    件   Z4   间接材料  1.536531    4    6.146123
# 34  D5     1   A3    1ml    件   Z5   间接材料  1.536353   10   15.363534
# 41  D6     4   A4    1ml    件   Z6   间接材料  0.834262   20   16.685239
# 47  D7     1   A4    1ml    件   Z6   间接材料  0.840164  150  126.024664

# %%
s3=df_jc.groupby('产品编码')['本期成本'].mean()
df3=pd.DataFrame({"间接材料平均单价":s3})
df3
# Out:
#       间接材料平均单价
# 产品编码
# A1    1.489599
# A2    1.547271
# A3    1.536353
# A4    0.837213

# %%
df_result=pd.concat([df1,df2,df3],axis=1)
df_result.loc['合计']=df_result.apply(lambda x:x.sum())
df_result=df_result.round(decimals=2)
df_result
# Out:
#        直接材料合计  直接材料平均单价  间接材料平均单价
# 产品编码
# A1     273.69     39.10      1.49
# A2    1011.86     53.26      1.55
# A3     725.18     72.52      1.54
# A4    1444.75     72.24      0.84
# 合计    3455.48    237.11      5.41

# %%
df_result.to_excel(r'C:\Users\shaoyumei\Desktop\输出结果.xlsx')
